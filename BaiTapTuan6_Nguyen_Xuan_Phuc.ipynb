# %%
#W6A1
check = [0]*1000000
arr = list(map(int,input().split()))
ans = []
for i in arr:
    if (check[i] == 0):
        check[i] = 1
        ans.append(i)

print(ans)
# Out:
#  1 8 7 3 8 2 3 4 5
# [1, 8, 7, 3, 2, 4, 5]

# %%
#W6A2
n = int(input())
arr = [0]
tmp = 0
for i in range (1, n+1):
    tmp += i
    arr.append(tmp)

print(arr)
# Out:
#  9
# [0, 1, 3, 6, 10, 15, 21, 28, 36, 45]

# %%
#W6A3
tup = tuple(map(int,input().split()))
k = int(input())
arr = []
for i in range (k, len(tup)):
    arr.append(tup[i])
for i in range (0,k):
    arr.append(tup[i])
arr = tuple(arr)
print(arr)
# Out:
#  1 2 3 4 5 6
#  3
# (4, 5, 6, 1, 2, 3)

# %%
#W6A4
dic = {}
s = list(map(str,(input().split())))
for i in range(0, len(s)):
    s[i] = s[i].split(":")
for i in range (0,len(s)):
    if (s[i][0] not in dic):
        dic[s[i][0]] = int(s[i][1])
    else:
        
        dic[s[i][0]] = list(dic[s[i][0]]).append(int(s[i][1]))
print(dic)
# print(int('8'))
# Out:
#  a:1 b:2 a:3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 10
#       8         dic[s[i][0]] = int(s[i][1])
#       9     else:
# ---> 10         dic[s[i][0]] = list(dic[s[i][0]]).append(int(s[i][1]))
#      11 print(dic)
#      12 # print(int('8'))
#
# TypeError: 'int' object is not iterable

# %%
#W6A5
arr = list(map(int,input().split()))
dic = {"positives": 0, "negatives": 0, "zeros": 0}
for i in arr:
    if (i > 0):
        dic["positives"] += 1
    elif (i < 0):
        dic["negatives"] += 1
    else:
        dic["zeros"] += 1

print(dic)
# Out:
#  0 9 8 0 2 3 1 3 2 -1 -2 -3 -4
# {'positives': 7, 'negatives': 4, 'zeros': 2}

# %%
#W6A6
arr = list(map(int,input().split()))
ans = 0
for i in arr:
    ans += i
print(ans)
# Out:
#  9 8 2 1 3 4 5
# 32

# %%
#W6A7
tup = tuple(map(int,input().split()))
tup_reverse = tuple(())
for i in range (len(tup)-1, -1, -1):
    #print((tup[i],))
    tup_reverse = tup_reverse + (tup[i],)
print(tup[0])
print(tup[-1])
print(tup_reverse)
# Out:
#  9 8 2 1 2 3 4 5 1 2 3
# 9
# 3
# (3, 2, 1, 5, 4, 3, 2, 1, 2, 8, 9)

# %%
#W6A8
arr = list(map(str, input().split()))
print(arr)
dic = {}
for i in arr:
    if (i in dic):
        dic[i] += 1
    else:
        dic[i] = 1
print(dic)
# Out:
#  Chelsea Ars Ars Ars Chelsea MU MU MC MC Liver
# ['Chelsea', 'Ars', 'Ars', 'Ars', 'Chelsea', 'MU', 'MU', 'MC', 'MC', 'Liver']
# {'Chelsea': 2, 'Ars': 3, 'MU': 2, 'MC': 2, 'Liver': 1}

# %%
#W6A11
tup = tuple(map(int,input().split()))
tup_odd = tuple(())
tup_even = tuple(())
for i in tup:
    if (i%2==0):
        tup_even = tup_even + (i,)
    else:
        tup_odd = tup_odd + (i,)
print(tup_even)
print(tup_odd)
# Out:
#  7 2 21 3 4 9 1 2 3 4 1 2 3 4 5
# (2, 4, 2, 4, 2, 4)
# (7, 21, 3, 9, 1, 3, 1, 3, 5)

# %%
#W6A10
def check(x1,y1,x2,y2):
    t1 = (x1,y1)
    t2 = (x2,y2)
    if (x1 < x2):
        return (t1)
    elif (x1 == x2):
        if (y1 < y2):
            return(t1)
        else:
            return(t2)
    else:
        return(t2)

arr = list(map(int,input().split()))
k = int(input())
ans = []
for i in range (0, len(arr)-1):
    for j in range (i+1, len(arr)):
        if (i != j):
            if (arr[i]+arr[j]==k):
                # for t in range (0, len(ans)-1):
                #     if (check(arr[i],arr[j],t[0],t[1]) == (arr[i],arr[j])):
                        ans.append((arr[i],arr[j]))
ans.sort()
print(ans)
# Out:
#  6 5 4 3 2 1
#  6
# [(4, 2), (5, 1)]

# %%
#W6A12
arr = list(map(int,input().split()))
dic = {}
for i in arr:
    if (i in dic):
        dic[i] += 1
    else:
        dic[i] = 1
cnt = -10000000
num = 1000000000

for i in dic.keys():
    if (dic[i] > cnt):
        cnt = dic[i]
        num = i
    elif (dic[i] == cnt):
        num = min(i,num)
#print(dic[8])
print(num)
# Out:
#  8 7 2 8 3 1 1 8 9 3
# 8

# %%
#W6A14
arr_1 = list(map(int,input().split()))
arr_2 = list(map(int,input().split()))
ans = []
for i in arr_1:
    if (i in arr_2):
        ans.append(i)
print(ans)
# Out:
#  1 2 3 4
#  2 3 4
# [2, 3, 4]

# %%
#W6A15
dic = {}
s = list(map(str,(input().split())))
k = int(input())
for i in range(0, len(s)):
    s[i] = s[i].split(":")
for i in range (0,len(s)):
    dic[s[i][0]] = int(s[i][1])
ans = {}
for i in dic.keys():
    if (dic[i] > k):
        ans[i] = dic[i]
print(ans)
# Out:
#  Chelsea:1 MU:2 MC:4
#  1
# {'MU': 2, 'MC': 4}

# %%
#W6A9
dic_1 = {}
dic_2 = {}
s1 = list(map(str,(input().split())))
s2 = list(map(str,(input().split())))
for i in range(0, len(s1)):
    s1[i] = s1[i].split(":")
for i in range(0, len(s2)):
    s2[i] = s2[i].split(":")
for i in range (0,len(s1)):
    dic_1[s1[i][0]] = int(s1[i][1])
for i in range (0,len(s2)):
    if (s2[i][0] in dic_1):
        dic_1[s2[i][0]] += int(s2[i][1])
    else:
        dic_1[s2[i][0]] = int(s2[i][1])
print(dic_1)
# Out:
#   Chelsea:1 MU:2 MC:4
#  Chelsea:1 MU:2 MC:10
# {'Chelsea': 2, 'MU': 4, 'MC': 14}
